# %% [markdown]
# # Causal identification
# DiD and IV estimates.

# %%
import pandas as pd
from pathlib import Path

for name in ["did_estimates.parquet", "iv_estimates.parquet"]:
    p = Path("data/processed/returns") / name
    if p.exists():
        display(pd.read_parquet(p))
