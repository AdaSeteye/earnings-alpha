# %% [markdown]
# # Data exploration
# Load raw transcripts, prices, and macro; summary stats.

# %%
import pandas as pd
from pathlib import Path

raw = Path("data/raw/transcripts")
if raw.exists():
    meta = pd.read_csv(raw / "_metadata.csv") if (raw / "_metadata.csv").exists() else None
    display(meta.head() if meta is not None else "No metadata")
else:
    print("Run ingestion first.")
