# %% [markdown]
# # Backtest analysis
# L/S portfolio performance.

# %%
import pandas as pd
from pathlib import Path

p = Path("data/processed/returns/backtest_results.parquet")
if p.exists():
    display(pd.read_parquet(p))
else:
    print("Run backtesting.portfolio_simulator first.")
