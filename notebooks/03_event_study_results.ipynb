# %% [markdown]
# # Event study results
# CAR and significance.

# %%
import pandas as pd
from pathlib import Path

p = Path("data/processed/returns/car_event_study.parquet")
if p.exists():
    df = pd.read_parquet(p)
    display(df)
else:
    print("Run causal.event_study first.")
